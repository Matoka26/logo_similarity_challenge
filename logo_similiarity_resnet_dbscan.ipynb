# %% [markdown]
# # Imports

# %%
from torchvision.models import resnet18, resnet50
import torchvision.transforms as transforms
import torch
import torch.nn as nn

from sklearn.cluster import DBSCAN
from tqdm import tqdm

import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import shutil
import os

# %% [markdown]
# # Data Paths

# %%
image_dir = '/kaggle/input/logo-similarity-data/data/extracted_logos/'
output_dir = '/kaggle/working/labeled_data'
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# # Transforms

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.CenterCrop((40, 40)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485], std=[0.229]),
    # transforms.GaussianBlur(51),
    # transforms.GaussianBlur(31),
])

transform_resnet = transforms.Compose([
    transforms.Resize((224, 224)),  # ResNet standard input size
    # transforms.CenterCrop((40, 40)),
    # transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %% [markdown]
# # Remove Transparency

# %%
def remove_transparency(im, bg_color=(255, 255, 255)):
    if im.mode == 'RGBA':
        # Create white RGB background and paste RGBA onto it using alpha
        bg = Image.new('RGB', im.size, bg_color)
        bg.paste(im, mask=im.split()[-1])  # Use alpha channel as mask
        return bg

    elif im.mode == 'LA':
        # Create white L background and paste LA onto it using alpha
        bg = Image.new('L', im.size, bg_color[0])  # Use first channel for grayscale
        bg.paste(im.convert('L'), mask=im.split()[-1])
        return bg

    elif im.mode in ('RGB', 'L'):
        return im  # No transparency — return as is

    else:
        # For any other mode, convert to RGB
        return im.convert('RGB')

# %% [markdown]
# # Feature Extraction

# %%
def process_image_from_path(path, channel='RGB', feature_extractor=None):
    img = Image.open(path).convert(channel)
    img = remove_transparency(img)
    
    if feature_extractor == 'resnet':
        img_tensor = transform_resnet(img)
    else:
        img_tensor = transform(img)
    
    return img_tensor

def get_resnet_features():
    model = resnet50(pretrained=True)
    model = nn.Sequential(*list(model.children())[:-1])  # Remove last FC layer
    model.eval()
    return model

def extract_features(model, img_tensor):
    with torch.no_grad():
        features = model(img_tensor.unsqueeze(0))
    return features.squeeze().flatten()

# %% [markdown]
# # Show random image

# %%
image_files = [f for f in os.listdir(image_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

idx = np.random.randint(len(image_files))

path = os.path.join(image_dir, image_files[idx])
img = process_image_from_path(path, channel='RGBA', feature_extractor='resnet')
img = img.permute(1, 2, 0).numpy()
plt.imshow(img)
plt.title(image_files[idx])
# Out:
# Text(0.5, 1.0, 'wurth.lk.png')

# %% [markdown]
# # Hyperparameters

# %%
hyperparams = {
    'eps': 2,
    'min_samples': 2
}

# %% [markdown]
# # Feature Extraction

# %%
resnet_model = get_resnet_features().to('cuda' if torch.cuda.is_available() else 'cpu')

resnet_features = []
for filename in tqdm(image_files, desc="Extracting ResNet features"):
    path = os.path.join(image_dir, filename)
    img_tensor = process_image_from_path(path, channel='RGB', feature_extractor='resnet')
    features = extract_features(resnet_model, img_tensor.to('cuda' if torch.cuda.is_available() else 'cpu'))
    resnet_features.append(features.cpu().numpy())

# Convert to numpy array for clustering
features_array = np.array(resnet_features)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Extracting ResNet features:   1%|          | 22/3356 [00:00<00:44, 75.03it/s] /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Extracting ResNet features: 100%|██████████| 3356/3356 [00:33<00:00, 99.50it/s]

# %% [markdown]
# # Fit DBSCAN

# %%
dbscan = DBSCAN(eps=hyperparams['eps'], min_samples=hyperparams['min_samples'])
labels = dbscan.fit_predict(features_array)

# %% [markdown]
# # Delete old dir

# %%
# !rm -rf labeled_data
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# # Correlate label and domain & Save
#
# ### Save each image starting with the label in the name for an easier navigation in a file explorer, the classes will be sorted and the class members will also be sorted by the domain name so the grouping will be a lot more visible

# %%
for filename, label in zip(image_files, labels):
    old_path = os.path.join(image_dir, filename)
    new_filename = f"{label}_{filename}"
    new_path = os.path.join(output_dir, new_filename)
    shutil.copy2(old_path, new_path)

# %% [markdown]
# # Count noise
# ### Count the images labeled as '-1' (noise/singular classes)

# %%
# !find labeled_data -maxdepth 1 -type f -name '-1*' | wc -l
# Out:
# 1634

# %% [markdown]
# # Count total files

# %%
# !find labeled_data -maxdepth 1 -type f | wc -l
# Out:
# 3356

# %% [markdown]
# # Save .zip

# %%
# !zip -r labeled_data.zip labeled_data
# Out:
# updating: labeled_data/ (stored 0%)
# updating: labeled_data/-1_pearson.com.cn.png (stored 0%)
# updating: labeled_data/-1_jdm.com.pe.png (deflated 2%)
# updating: labeled_data/-1_linde.co.th.png (deflated 1%)
# updating: labeled_data/-1_duracleanservicebybob.com.png (deflated 0%)
# updating: labeled_data/-1_vendhq.com.png (deflated 0%)
# updating: labeled_data/-1_toyotanorthedsa.com.png (deflated 1%)
# updating: labeled_data/-1_avis-taiwan.com.png (deflated 3%)
# updating: labeled_data/-1_ambiderm.com.gt.png (deflated 4%)
# updating: labeled_data/-1_kiamotors.com.kh.png (deflated 3%)
# updating: labeled_data/-1_medef41.fr.png (stored 0%)
# updating: labeled_data/-1_santillana.com.ec.png (stored 0%)
# updating: labeled_data/-1_mitsubishielectric.cz.png (deflated 3%)
# updating: labeled_data/-1_chicco.ch.png (deflated 2%)
# updating: labeled_data/-1_pearsonclinical.ca.png (deflated 0%)
# updating: labeled_data/-1_sprachschule-aktiv.de.png (stored 0%)
# updating: labeled_data/-1_toyotasouthern.com.png (deflated 0%)
# updating: labeled_data/-1_mariagefreres.co.jp.png (deflated 0%)
# updating: labeled_data/-1_fleishmanhillard.com.br.png (stored 0%)
# updating: labeled_data/3_spitex-aarenord.ch.png (deflated 2%)
# updating: labeled_data/-1_pingusenglish.ac.th.png (stored 0%)
# updating: labeled_data/-1_mazda-bielskobiala-autogazda.pl.png (deflated 2%)
# updating: labeled_data/-1_inductotherm.com.tr.png (deflated 5%)
# updating: labeled_data/-1_hyundaicentralsales.com.png (deflated 1%)
# updating: labeled_data/-1_cinnabonrussia.com.png (deflated 0%)
# updating: labeled_data/-1_tgmresearch.vn.png (deflated 17%)
# updating: labeled_data/-1_ikea.com.do.png (deflated 6%)
# updating: labeled_data/-1_servier.ru.png (stored 0%)
# updating: labeled_data/-1_chicco.com.ua.png (deflated 2%)
# updating: labeled_data/-1_decathlon.pl.png (deflated 4%)
# updating: labeled_data/-1_toyotatokullar.com.tr.png (deflated 2%)
# updating: labeled_data/-1_sitechnorthwest.com.png (stored 0%)
# updating: labeled_data/-1_decathlon.com.kh.png (deflated 4%)
# updating: labeled_data/-1_takab.nu.png (stored 0%)
# updating: labeled_data/-1_julis-sachsenanhalt.de.png (deflated 0%)
# updating: labeled_data/-1_adlatus-nordwestschweiz.ch.png (deflated 36%)
# updating: labeled_data/-1_jungheinrich.in.png (deflated 1%)
# updating: labeled_data/-1_shopee.in.png (deflated 1%)
# updating: labeled_data/-1_actemium.se.png (deflated 1%)
# updating: labeled_data/-1_savethechildren.org.za.png (deflated 1%)
# updating: labeled_data/-1_saint-gobain.al.png (deflated 2%)
# updating: labeled_data/-1_solidea.co.za.png (deflated 3%)
# updating: labeled_data/-1_actemium.ch.png (deflated 2%)
# updating: labeled_data/-1_nikon-mea.com.png (stored 0%)
# updating: labeled_data/-1_daad-australia.org.png (deflated 13%)
# updating: labeled_data/-1_renaultecatepec.com.mx.png (stored 0%)
# updating: labeled_data/-1_pilotpen.hu.png (stored 0%)
# updating: labeled_data/-1_srpb2b.com.png (stored 0%)
# updating: labeled_data/-1_bigfootdigital.co.uk.png (deflated 6%)
# updating: labeled_data/-1_toyotabakircilarfethiye.com.tr.png (deflated 1%)
# updating: labeled_data/-1_wwf.org.nz.png (deflated 1%)
# updating: labeled_data/-1_printsasia.com.png (stored 0%)
# updating: labeled_data/-1_nutriciavoorjou.nl.png (stored 0%)
# updating: labeled_data/-1_digilite.com.au.png (deflated 5%)
# updating: labeled_data/-1_ecochillers.net.png (stored 0%)
# updating: labeled_data/-1_pkfgf.co.nz.png (stored 0%)
# updating: labeled_data/-1_avia-ramonville.fr.png (stored 0%)
# updating: labeled_data/-1_howdengroupholdings.com.png (deflated 3%)
# updating: labeled_data/-1_bcurelaser.co.il.png (deflated 1%)
# updating: labeled_data/-1_aonsolutions.com.cy.png (deflated 3%)
# updating: labeled_data/-1_carlsjr.es.png (stored 0%)
# updating: labeled_data/-1_cuponesybeneficios.com.co.png (deflated 18%)
# updating: labeled_data/-1_crocs.co.nz.png (stored 0%)
# updating: labeled_data/-1_actemium.id.png (stored 0%)
# updating: labeled_data/-1_toofacedcosmetics.jp.png (deflated 0%)
# updating: labeled_data/-1_tapflo.nl.png (deflated 0%)
# updating: labeled_data/-1_fmc-mexico.com.png (stored 0%)
# updating: labeled_data/-1_chicco.com.tw.png (stored 0%)
# updating: labeled_data/9_bakertilly.site.png (stored 0%)
# updating: labeled_data/-1_actemium.it.png (deflated 5%)
# updating: labeled_data/-1_manpowergroup.dk.png (deflated 0%)
# updating: labeled_data/-1_isover.ie.png (deflated 1%)
# updating: labeled_data/-1_modshair-mannheim.de.png (stored 0%)
# updating: labeled_data/-1_cdlcuritiba.org.br.png (deflated 2%)
# updating: labeled_data/-1_cdljatai.com.br.png (stored 0%)
# updating: labeled_data/-1_culliganbetterwater.com.png (deflated 2%)
# updating: labeled_data/-1_crif.pl.png (deflated 3%)
# updating: labeled_data/-1_pamline.fr.png (deflated 2%)
# updating: labeled_data/-1_mcdonalds.ma.png (stored 0%)
# updating: labeled_data/-1_myron.ca.png (deflated 0%)
# updating: labeled_data/-1_reallifeconcepts.co.za.png (deflated 4%)
# updating: labeled_data/-1_reedglobal.ch.png (deflated 42%)
# updating: labeled_data/-1_renaultamericas.com.mx.png (deflated 2%)
# updating: labeled_data/-1_portadoors.com.png (stored 0%)
# updating: labeled_data/-1_orange.cd.png (deflated 7%)
# updating: labeled_data/-1_berlitzph.com.png (deflated 3%)
# updating: labeled_data/1_daikin-ksa.com.png (deflated 4%)
# updating: labeled_data/-1_isover.de.png (deflated 5%)
# updating: labeled_data/-1_medef-ardennes.com.png (deflated 1%)
# updating: labeled_data/-1_wwf.or.th.png (deflated 2%)
# updating: labeled_data/-1_jollibee.com.bn.png (stored 0%)
# updating: labeled_data/-1_carlsjr.co.nz.png (deflated 1%)
# updating: labeled_data/-1_spitex-kriens.ch.png (deflated 2%)
# updating: labeled_data/-1_honda-melun.com.png (stored 0%)
# updating: labeled_data/-1_affinitynonprofits.com.png (deflated 1%)
# updating: labeled_data/-1_mazdaofcolumbia.com.png (deflated 4%)
# updating: labeled_data/-1_menicon.sg.png (stored 0%)
# updating: labeled_data/-1_veolia.am.png (stored 0%)
# updating: labeled_data/2_aonsolutions.com.tr.png (deflated 21%)
# updating: labeled_data/-1_mazdaoflodi.com.png (deflated 1%)
# updating: labeled_data/-1_vkf-renzel.bg.png (stored 0%)
# updating: labeled_data/-1_seats2meetstationdenbosch.nl.png (stored 0%)
# updating: labeled_data/-1_greatplacetowork.pt.png (deflated 0%)
# updating: labeled_data/-1_amnesty.org.ph.png (deflated 3%)
# updating: labeled_data/-1_culliganslc.com.png (stored 0%)
# updating: labeled_data/-1_vkf-renzel.hu.png (stored 0%)
# updating: labeled_data/-1_mondialparebrise.re.png (stored 0%)
# updating: labeled_data/-1_hyundaigatineau.ca.png (stored 0%)
# updating: labeled_data/-1_kalyanmachines.com.png (stored 0%)
# updating: labeled_data/-1_experianacademy.com.png (deflated 0%)
# updating: labeled_data/-1_toyota-corbeil.fr.png (deflated 1%)
# updating: labeled_data/-1_atalian.cz.png (deflated 0%)
# updating: labeled_data/-1_sixty8.ro.png (stored 0%)
# updating: labeled_data/-1_nordicpharma.es.png (deflated 1%)
# updating: labeled_data/1_daikinmea.com.png (deflated 4%)
# updating: labeled_data/-1_duracleanservices.net.png (stored 0%)
# updating: labeled_data/-1_kentmaster.nz.png (deflated 0%)
# updating: labeled_data/-1_santander.pt.png (stored 0%)
# updating: labeled_data/-1_bimedasuramerica.com.png (stored 0%)
# updating: labeled_data/-1_azets.ie.png (deflated 1%)
# updating: labeled_data/-1_keytitlegroupsa.com.png (deflated 3%)
# updating: labeled_data/-1_altengt.com.png (deflated 51%)
# updating: labeled_data/-1_vbh.hr.png (deflated 6%)
# updating: labeled_data/-1_culligansouthwest.com.png (stored 0%)
# updating: labeled_data/-1_sonepar.cz.png (stored 0%)
# updating: labeled_data/-1_subaruvilnius.lt.png (deflated 4%)
# updating: labeled_data/-1_honda.com.ng.png (deflated 4%)
# updating: labeled_data/1_daikin-iraq.com.png (deflated 4%)
# updating: labeled_data/-1_eurofins.hr.png (stored 0%)
# updating: labeled_data/-1_crif.cz.png (stored 0%)
# updating: labeled_data/-1_santander.de.png (deflated 1%)
# updating: labeled_data/-1_sprachcaffe-muenchen.com.png (deflated 23%)
# updating: labeled_data/-1_honda-autoland.com.png (stored 0%)
# updating: labeled_data/-1_toyotatoyan.com.tr.png (deflated 1%)
# updating: labeled_data/-1_subaru.com.pa.png (deflated 2%)
# updating: labeled_data/-1_msig-asia.com.png (stored 0%)
# updating: labeled_data/-1_wurth.kz.png (deflated 2%)
# updating: labeled_data/-1_wurthsaudi.com.png (deflated 0%)
# updating: labeled_data/-1_solatube.co.uk.png (deflated 4%)
# updating: labeled_data/-1_landish.ca.png (stored 0%)
# updating: labeled_data/-1_piccinifuels.it.png (stored 0%)
# updating: labeled_data/-1_sofrecogroup.com.png (deflated 4%)
# updating: labeled_data/-1_svnchicagopm.com.png (deflated 1%)
# updating: labeled_data/-1_wurth.nl.png (deflated 0%)
# updating: labeled_data/-1_mercyships.be.png (deflated 1%)
# updating: labeled_data/-1_crocssa.co.za.png (deflated 3%)
# updating: labeled_data/-1_aquatherm-belux.be.png (deflated 1%)
# updating: labeled_data/-1_pingusenglishbd.com.png (stored 0%)
# updating: labeled_data/-1_abc-autoglas.de.png (stored 0%)
# updating: labeled_data/7_bbraun.co.in.png (deflated 1%)
# updating: labeled_data/-1_whisky.de.png (deflated 3%)
# updating: labeled_data/-1_muvpropiedades.com.ar.png (deflated 8%)
# updating: labeled_data/-1_ringcontainers.co.uk.png (deflated 0%)
# updating: labeled_data/-1_eresrelocation.es.png (deflated 3%)
# updating: labeled_data/-1_mcdonalds.co.za.png (deflated 1%)
# updating: labeled_data/-1_renaultselection.co.za.png (stored 0%)
# updating: labeled_data/-1_mffshopen.se.png (stored 0%)
# updating: labeled_data/-1_allianz-assistance.ie.png (stored 0%)
# updating: labeled_data/-1_pacificinfotech.co.uk.png (stored 0%)
# updating: labeled_data/-1_desjoyauxgh.com.png (stored 0%)
# updating: labeled_data/-1_daikindevice.cz.png (stored 0%)
# updating: labeled_data/-1_europa-union-hessen.de.png (stored 0%)
# updating: labeled_data/-1_budgetqatar.com.png (deflated 2%)
# updating: labeled_data/-1_nelsonlabsbozeman.com.png (deflated 5%)
# updating: labeled_data/-1_svntrinity.com.png (deflated 2%)
# updating: labeled_data/-1_hsusports.com.png (stored 0%)
# updating: labeled_data/-1_intersport-rent.fr.png (deflated 1%)
# updating: labeled_data/-1_kiaofmuncie.com.png (stored 0%)
# updating: labeled_data/-1_linexcoloradosprings.com.png (stored 0%)
# updating: labeled_data/-1_spp.cz.png (deflated 3%)
# updating: labeled_data/-1_actemium.pt.png (deflated 6%)
# updating: labeled_data/-1_johcm-ukconference.com.png (stored 0%)
# updating: labeled_data/-1_unglobalcompactghana.com.png (deflated 0%)
# updating: labeled_data/-1_avis.nc.png (deflated 4%)
# updating: labeled_data/-1_mitsubishi-motors.it.png (deflated 1%)
# updating: labeled_data/-1_toupret.ch.png (deflated 3%)
# updating: labeled_data/-1_pkf-hk.com.png (deflated 4%)
# updating: labeled_data/-1_toyotahonduras.com.png (deflated 2%)
# updating: labeled_data/-1_cdvibenelux.com.png (stored 0%)
# updating: labeled_data/1_daikinbahrain.com.png (deflated 4%)
# updating: labeled_data/-1_salvationarmyflorida.org.png (stored 0%)
# updating: labeled_data/-1_mazda.hu.png (deflated 1%)
# updating: labeled_data/-1_buffalotours.es.png (deflated 1%)
# updating: labeled_data/-1_mercyships.fr.png (deflated 1%)
# updating: labeled_data/-1_manpowergroup.no.png (deflated 2%)
# updating: labeled_data/-1_lamborghini-frankfurt.com.png (stored 0%)
# updating: labeled_data/-1_ecotec-usa.com.png (deflated 14%)
# updating: labeled_data/-1_shimadzumea.com.png (stored 0%)
# updating: labeled_data/-1_mazdaofmilford.com.png (stored 0%)
# updating: labeled_data/-1_furuno.gr.png (deflated 3%)
# updating: labeled_data/-1_aon.lt.png (deflated 5%)
# updating: labeled_data/-1_isuzu-vietnam.com.png (stored 0%)
# updating: labeled_data/-1_zkteco.com.bd.png (deflated 3%)
# updating: labeled_data/-1_edf-re.com.au.png (deflated 2%)
# updating: labeled_data/-1_jysk.mk.png (deflated 2%)
# updating: labeled_data/-1_crocs.com.ec.png (stored 0%)
# updating: labeled_data/-1_eccreditcontrol.com.au.png (deflated 3%)
# updating: labeled_data/-1_menicon.co.uk.png (deflated 0%)
# updating: labeled_data/-1_synlab.com.cy.png (deflated 21%)
# updating: labeled_data/-1_brother.com.br.png (deflated 4%)
# updating: labeled_data/-1_grantthornton.com.sv.png (deflated 0%)
# updating: labeled_data/-1_ibc-solar.es.png (deflated 3%)
# updating: labeled_data/-1_future-x.at.png (stored 0%)
# updating: labeled_data/-1_invisalign.co.il.png (stored 0%)
# updating: labeled_data/-1_nobleprog.es.png (deflated 4%)
# updating: labeled_data/-1_mazdadesherbrooke.com.png (stored 0%)
# updating: labeled_data/-1_overheaddoormankato.com.png (deflated 0%)
# updating: labeled_data/-1_teztour.lt.png (deflated 1%)
# updating: labeled_data/-1_rjelinek.cl.png (deflated 3%)
# updating: labeled_data/-1_securitas24.de.png (deflated 9%)
# updating: labeled_data/-1_cardif.pl.png (deflated 3%)
# updating: labeled_data/-1_powerint.cn.png (deflated 2%)
# updating: labeled_data/-1_cinnabon.com.tr.png (deflated 6%)
# updating: labeled_data/-1_greatplacetowork.co.ke.png (stored 0%)
# updating: labeled_data/-1_sans-sans.com.my.png (deflated 10%)
# updating: labeled_data/-1_crif.ch.png (deflated 3%)
# updating: labeled_data/-1_pearsonactivelearn.com.png (stored 0%)
# updating: labeled_data/-1_toyotayatumugla.com.tr.png (deflated 2%)
# updating: labeled_data/-1_salvationarmyconcordca.org.png (stored 0%)
# updating: labeled_data/-1_rheine.schule.png (deflated 2%)
# updating: labeled_data/-1_daikin.com.vn.png (stored 0%)
# updating: labeled_data/-1_mycabin.ie.png (deflated 5%)
# updating: labeled_data/-1_ikea.pr.png (deflated 5%)
# updating: labeled_data/-1_mtn.com.gh.png (deflated 3%)
# updating: labeled_data/-1_hahn-kolb.mx.png (stored 0%)
# updating: labeled_data/-1_smittysmb.ca.png (deflated 1%)
# updating: labeled_data/1_daikin.ru.png (deflated 4%)
# updating: labeled_data/-1_equans.hu.png (deflated 4%)
# updating: labeled_data/-1_vans.com.ar.png (deflated 7%)
# updating: labeled_data/-1_krautzberger.pl.png (deflated 4%)
# updating: labeled_data/3_spitex-region-kreuzlingen.ch.png (deflated 2%)
# updating: labeled_data/-1_isover.sk.png (deflated 20%)
# updating: labeled_data/-1_dhirajsonsonline.com.png (stored 0%)
# updating: labeled_data/-1_promstahl.de.png (stored 0%)
# updating: labeled_data/-1_martinavenueshops.com.png (stored 0%)
# updating: labeled_data/-1_cfmotoindia.com.png (deflated 1%)
# updating: labeled_data/-1_etxt.biz.png (stored 0%)
# updating: labeled_data/-1_tchibo.cz.png (deflated 1%)
# updating: labeled_data/-1_nordicpharma.pt.png (deflated 53%)
# updating: labeled_data/2_aonsolutions.gr.png (deflated 21%)
# updating: labeled_data/-1_takedaoncology.com.png (deflated 2%)
# updating: labeled_data/8_pkfboston.com.png (deflated 3%)
# updating: labeled_data/-1_papajohns.com.pk.png (deflated 1%)
# updating: labeled_data/-1_ford.cl.png (stored 0%)
# updating: labeled_data/-1_gulfoil.co.uk.png (stored 0%)
# updating: labeled_data/-1_subaru.lu.png (stored 0%)
# updating: labeled_data/-1_lindegas.hu.png (stored 0%)
# updating: labeled_data/-1_medicover.de.png (deflated 2%)
# updating: labeled_data/-1_despec.eu.png (stored 0%)
# updating: labeled_data/-1_mazdaofportcharlotte.com.png (stored 0%)
# updating: labeled_data/-1_santillana.com.uy.png (stored 0%)
# updating: labeled_data/-1_goliathgames.de.png (deflated 1%)
# updating: labeled_data/-1_dilmahtea.co.uk.png (stored 0%)
# updating: labeled_data/-1_intersport-gros.de.png (stored 0%)
# updating: labeled_data/7_bbraun.ae.png (deflated 1%)
# updating: labeled_data/-1_mercyships.nl.png (deflated 0%)
# updating: labeled_data/-1_snapologyfranchising.com.png (stored 0%)
# updating: labeled_data/-1_unitecnica-us.com.png (deflated 3%)
# updating: labeled_data/-1_avia.ch.png (deflated 4%)
# updating: labeled_data/-1_wwfcz.org.png (stored 0%)
# updating: labeled_data/-1_hps-guns.de.png (deflated 3%)
# updating: labeled_data/-1_budgetglacier.com.png (stored 0%)
# updating: labeled_data/-1_innolytics.net.png (stored 0%)
# updating: labeled_data/-1_decathlon.ro.png (deflated 5%)
# updating: labeled_data/-1_bakertilly.uy.png (deflated 0%)
# updating: labeled_data/-1_insize.com.br.png (stored 0%)
# updating: labeled_data/-1_mitsubishielectric.se.png (deflated 3%)
# updating: labeled_data/-1_plameco-bonn.de.png (stored 0%)
# updating: labeled_data/-1_kiaofbillings.com.png (stored 0%)
# updating: labeled_data/-1_telehouse.co.th.png (stored 0%)
# updating: labeled_data/-1_bakertilly.gt.png (stored 0%)
# updating: labeled_data/-1_adeccojapanese.asia.png (deflated 3%)
# updating: labeled_data/-1_metlife.co.kr.png (deflated 1%)
# updating: labeled_data/-1_landermitsubishi.com.au.png (deflated 2%)
# updating: labeled_data/-1_actemium.com.br.png (deflated 1%)
# updating: labeled_data/-1_mazda.com.sg.png (deflated 3%)
# updating: labeled_data/-1_idealindustries.cn.png (stored 0%)
# updating: labeled_data/-1_mcdonalds.com.jo.png (stored 0%)
# updating: labeled_data/-1_manpowergroup.ca.png (stored 0%)
# updating: labeled_data/-1_lamborghini-stuttgart.com.png (deflated 4%)
# updating: labeled_data/9_bakertilly.com.cy.png (stored 0%)
# updating: labeled_data/-1_orange-bissau.com.png (deflated 3%)
# updating: labeled_data/-1_orange.sn.png (stored 0%)
# updating: labeled_data/-1_mazda.com.kh.png (deflated 2%)
# updating: labeled_data/-1_canon-its.co.jp.png (stored 0%)
# updating: labeled_data/-1_pearsonclinical.es.png (deflated 2%)
# updating: labeled_data/-1_abilways.be.png (deflated 46%)
# updating: labeled_data/-1_novonordisk.my.png (deflated 1%)
# updating: labeled_data/-1_decathlon.ch.png (deflated 2%)
# updating: labeled_data/-1_biolchim.com.br.png (deflated 2%)
# updating: labeled_data/-1_allianzlifebali.com.png (stored 0%)
# updating: labeled_data/-1_acetoolonline.com.png (deflated 2%)
# updating: labeled_data/-1_mazdaofwestridge.com.png (stored 0%)
# updating: labeled_data/-1_metagenics.co.jp.png (deflated 4%)
# updating: labeled_data/-1_howdenoze.pl.png (deflated 3%)
# updating: labeled_data/-1_europa-union-thueringen.de.png (deflated 1%)
# updating: labeled_data/-1_habitatns.ca.png (stored 0%)
# updating: labeled_data/-1_repsolresourcesuk.com.png (deflated 2%)
# updating: labeled_data/-1_hertz.yt.png (deflated 13%)
# updating: labeled_data/-1_foxinaboxlondon.uk.png (deflated 3%)
# updating: labeled_data/-1_cvjm-hemer.de.png (stored 0%)
# updating: labeled_data/-1_julis-mfr.de.png (deflated 0%)
# updating: labeled_data/-1_ibc-solar.cz.png (deflated 1%)
# updating: labeled_data/-1_plameco-baer.de.png (stored 0%)
# updating: labeled_data/-1_wurth.ua.png (deflated 1%)
# updating: labeled_data/-1_thebodyshop.bg.png (stored 0%)
# updating: labeled_data/-1_compo.de.png (stored 0%)
# updating: labeled_data/-1_ekartlogistics.in.png (deflated 3%)
# updating: labeled_data/-1_grantthornton.com.ve.png (stored 0%)
# updating: labeled_data/-1_subaru.jp.png (deflated 3%)
# updating: labeled_data/-1_nepaltrust.gov.np.png (stored 0%)
# updating: labeled_data/-1_engieindia.com.png (deflated 2%)
# updating: labeled_data/-1_bauwerk-group.hr.png (deflated 1%)
# updating: labeled_data/-1_infiniti.com.tw.png (deflated 5%)
# updating: labeled_data/-1_despat.com.png (stored 0%)
# updating: labeled_data/-1_mazdanorkar.com.png (stored 0%)
# updating: labeled_data/-1_ymcasf.org.png (deflated 1%)
# updating: labeled_data/-1_yves-rocher.pt.png (stored 0%)
# updating: labeled_data/-1_actemium.de.png (deflated 1%)
# updating: labeled_data/-1_cedstone.ca.png (stored 0%)
# updating: labeled_data/1_daikinafrica.com.png (deflated 4%)
# updating: labeled_data/-1_remax-emblema.com.ar.png (stored 0%)
# updating: labeled_data/-1_xwiftracingevents.be.png (deflated 2%)
# updating: labeled_data/-1_path-solutions.com.png (stored 0%)
# updating: labeled_data/-1_engenmauritius.com.png (deflated 1%)
# updating: labeled_data/-1_ccusa.ca.png (deflated 1%)
# updating: labeled_data/-1_humanasecondhand.se.png (deflated 17%)
# updating: labeled_data/-1_honda-montpellier.com.png (deflated 1%)
# updating: labeled_data/-1_nissantireadvantage.com.png (stored 0%)
# updating: labeled_data/-1_nissanofgardencity.com.png (stored 0%)
# updating: labeled_data/-1_crocs.com.pe.png (deflated 3%)
# updating: labeled_data/-1_crif.hk.png (deflated 3%)
# updating: labeled_data/-1_starkeypro.de.png (deflated 1%)
# updating: labeled_data/-1_job-impulse.co.jp.png (deflated 7%)
# updating: labeled_data/-1_kamic.fi.png (stored 0%)
# updating: labeled_data/9_bakertillygh.com.png (stored 0%)
# updating: labeled_data/9_bakertilly-ca.com.png (stored 0%)
# updating: labeled_data/-1_mazdalanka.lk.png (deflated 4%)
# updating: labeled_data/7_bbraun.co.za.png (deflated 1%)
# updating: labeled_data/-1_hollandandbarrett.com.mt.png (stored 0%)
# updating: labeled_data/-1_minisocr.com.png (deflated 2%)
# updating: labeled_data/-1_worldvision.com.au.png (stored 0%)
# updating: labeled_data/-1_drekopf-kanalservice.de.png (deflated 1%)
# updating: labeled_data/-1_propertyfinder.com.png (deflated 1%)
# updating: labeled_data/-1_cubcadet.fr.png (stored 0%)
# updating: labeled_data/-1_takeda.nl.png (deflated 3%)
# updating: labeled_data/-1_adecco.rs.png (deflated 0%)
# updating: labeled_data/-1_isuzuhanoi.com.png (stored 0%)
# updating: labeled_data/-1_carlsjr-russia.ru.png (stored 0%)
# updating: labeled_data/-1_renault-guilers.fr.png (deflated 59%)
# updating: labeled_data/-1_trisa.bg.png (stored 0%)
# updating: labeled_data/-1_aeccglobal.lk.png (deflated 5%)
# updating: labeled_data/-1_ardex.de.png (deflated 3%)
# updating: labeled_data/-1_sonepar.co.png (stored 0%)
# updating: labeled_data/-1_jungheinrich.com.br.png (deflated 1%)
# updating: labeled_data/-1_starbucks.com.sg.png (deflated 1%)
# updating: labeled_data/-1_aonhewitt.com.cy.png (stored 0%)
# updating: labeled_data/-1_pkfthailand.asia.png (deflated 2%)
# updating: labeled_data/-1_experian.com.my.png (stored 0%)
# updating: labeled_data/-1_terradat.co.uk.png (deflated 3%)
# updating: labeled_data/-1_daikin.com.mm.png (stored 0%)
# updating: labeled_data/-1_rubiomonocoatusa.com.png (deflated 0%)
# updating: labeled_data/-1_spitex-waedenswil.ch.png (deflated 3%)
# updating: labeled_data/-1_ymcalouisville.org.png (deflated 0%)
# updating: labeled_data/9_bakertilly.lu.png (stored 0%)
# updating: labeled_data/-1_batistareisfloresonline.com.br.png (stored 0%)
# updating: labeled_data/-1_intersport.sk.png (stored 0%)
# updating: labeled_data/-1_subaru.com.tr.png (deflated 3%)
# updating: labeled_data/7_bbraun.co.kr.png (deflated 1%)
# updating: labeled_data/-1_daikincareers.com.png (deflated 5%)
# updating: labeled_data/-1_subway.com.tw.png (stored 0%)
# updating: labeled_data/-1_accelltherapy.com.au.png (stored 0%)
# updating: labeled_data/-1_mazda-autohaus-huck-buehl.de.png (deflated 2%)
# updating: labeled_data/-1_budget.bg.png (stored 0%)
# updating: labeled_data/-1_papajohns.co.nl.png (stored 0%)
# updating: labeled_data/7_bbraun.hu.png (deflated 1%)
# updating: labeled_data/-1_starkey.com.co.png (deflated 1%)
# updating: labeled_data/-1_microbit.nl.png (stored 0%)
# updating: labeled_data/-1_algeco.pt.png (deflated 3%)
# updating: labeled_data/-1_lindt.es.png (deflated 2%)
# updating: labeled_data/-1_decathlon.hu.png (deflated 3%)
# updating: labeled_data/-1_andre-media.it.png (deflated 2%)
# updating: labeled_data/-1_exertisztorm.com.png (stored 0%)
# updating: labeled_data/-1_pepsico.ua.png (deflated 0%)
# updating: labeled_data/-1_wurth.com.uy.png (deflated 0%)
# updating: labeled_data/-1_thegoodlobby.fr.png (deflated 0%)
# updating: labeled_data/-1_toolstationjobs.nl.png (stored 0%)
# updating: labeled_data/-1_kalorimeta-singen.de.png (stored 0%)
# updating: labeled_data/-1_avia.nl.png (deflated 0%)
# updating: labeled_data/-1_linde-gas.lt.png (deflated 3%)
# updating: labeled_data/-1_nissanofopelousas.com.png (deflated 2%)
# updating: labeled_data/-1_sprachschule-aktiv-passau.de.png (deflated 3%)
# updating: labeled_data/-1_nikonlenswear.cn.png (deflated 15%)
# updating: labeled_data/-1_kumon.com.hk.png (deflated 7%)
# updating: labeled_data/-1_attijariwafabank.com.eg.png (deflated 3%)
# updating: labeled_data/-1_rexel.it.png (deflated 4%)
# updating: labeled_data/-1_honda.cl.png (stored 0%)
# updating: labeled_data/-1_amnesty.id.png (deflated 2%)
# updating: labeled_data/-1_hertz-autopozicovna.sk.png (deflated 17%)
# updating: labeled_data/-1_yvesrocher.com.tr.png (stored 0%)
# updating: labeled_data/-1_bnpparibasdeveloppement.com.png (deflated 3%)
# updating: labeled_data/-1_nissanattheavenues.com.png (stored 0%)
# updating: labeled_data/-1_stockco.co.nz.png (deflated 5%)
# updating: labeled_data/-1_tectake.it.png (deflated 4%)
# updating: labeled_data/-1_repsolsolgas.com.png (deflated 1%)
# updating: labeled_data/-1_mazda.ph.png (deflated 3%)
# updating: labeled_data/-1_kierpensions.co.uk.png (stored 0%)
# updating: labeled_data/-1_reedglobal.com.mt.png (deflated 0%)
# updating: labeled_data/-1_domcortraffic.ca.png (deflated 3%)
# updating: labeled_data/-1_yves-rocher.nl.png (deflated 2%)
# updating: labeled_data/-1_getscsadmin.com.png (deflated 1%)
# updating: labeled_data/-1_cvjm-pfalz.de.png (deflated 8%)
# updating: labeled_data/-1_adra.sk.png (deflated 2%)
# updating: labeled_data/-1_hyundai.ge.png (deflated 5%)
# updating: labeled_data/-1_santillana.com.bo.png (deflated 0%)
# updating: labeled_data/-1_cdljovem.org.br.png (deflated 3%)
# updating: labeled_data/-1_caspak.co.nz.png (stored 0%)
# updating: labeled_data/-1_canonburgos.com.png (stored 0%)
# updating: labeled_data/-1_isover.at.png (deflated 4%)
# updating: labeled_data/-1_linexps.com.png (stored 0%)
# updating: labeled_data/-1_mazda-uae.com.png (deflated 2%)
# updating: labeled_data/-1_aamcoredlandsca.com.png (stored 0%)
# updating: labeled_data/-1_pepsico.fr.png (deflated 0%)
# updating: labeled_data/-1_cleijsenautoschadegoirle.nl.png (deflated 6%)
# updating: labeled_data/-1_benu.lt.png (deflated 2%)
# updating: labeled_data/-1_pkfcabrera.com.png (deflated 0%)
# updating: labeled_data/-1_spiegse.com.png (stored 0%)
# updating: labeled_data/-1_kiaofduluth.com.png (deflated 1%)
# updating: labeled_data/-1_mitsubishi-motors.at.png (deflated 0%)
# updating: labeled_data/-1_sto-sea.com.png (deflated 6%)
# updating: labeled_data/-1_intersport.com.tr.png (deflated 3%)
# updating: labeled_data/-1_xella-colloquium.berlin.png (deflated 2%)
# updating: labeled_data/-1_sonepar.com.sg.png (deflated 1%)
# updating: labeled_data/-1_aamcoutah.com.png (deflated 1%)
# updating: labeled_data/-1_acuraofwappingersfalls.com.png (stored 0%)
# updating: labeled_data/-1_carglass.ee.png (deflated 7%)
# updating: labeled_data/-1_sanlorenzo.com.pe.png (deflated 2%)
# updating: labeled_data/-1_ymcawaycross.com.png (deflated 1%)
# updating: labeled_data/-1_tupperware.at.png (deflated 4%)
# updating: labeled_data/-1_monitus.com.png (stored 0%)
# updating: labeled_data/-1_wwf.no.png (deflated 2%)
# updating: labeled_data/-1_furuno.co.uk.png (deflated 2%)
# updating: labeled_data/-1_seitenbachershop.com.png (stored 0%)
# updating: labeled_data/-1_ford.dn.ua.png (stored 0%)
# updating: labeled_data/-1_crocs.co.id.png (deflated 8%)
# updating: labeled_data/-1_deheus.id.png (deflated 0%)
# updating: labeled_data/-1_bakertilly.sl.png (deflated 0%)
# updating: labeled_data/-1_allianzpp.com.png (stored 0%)
# updating: labeled_data/-1_wuerth.co.jp.png (deflated 1%)
# updating: labeled_data/-1_mazda-ma.com.png (deflated 2%)
# updating: labeled_data/-1_pkffinconta.ro.png (deflated 4%)
# updating: labeled_data/-1_aiesec.org.rs.png (stored 0%)
# updating: labeled_data/-1_filterteknik.dk.png (deflated 1%)
# updating: labeled_data/-1_dopplerumbrellas.com.au.png (deflated 0%)
# updating: labeled_data/-1_fft-ps.pl.png (deflated 3%)
# updating: labeled_data/9_bakertilly.ec.png (stored 0%)
# updating: labeled_data/-1_benu.nl.png (stored 0%)
# updating: labeled_data/-1_siiora.org.png (deflated 3%)
# updating: labeled_data/-1_orange.com.lr.png (deflated 3%)
# updating: labeled_data/-1_athora.nl.png (stored 0%)
# updating: labeled_data/-1_compassion.es.png (stored 0%)
# updating: labeled_data/-1_allianzlifechanger.com.png (stored 0%)
# updating: labeled_data/-1_intersport.hu.png (deflated 0%)
# updating: labeled_data/-1_isic.fr.png (stored 0%)
# updating: labeled_data/-1_toyotaalbania.al.png (deflated 83%)
# updating: labeled_data/-1_nhszketpo.hu.png (deflated 3%)
# updating: labeled_data/-1_modshair-nuernberg.de.png (deflated 2%)
# updating: labeled_data/9_bakertilly.bg.png (stored 0%)
# updating: labeled_data/-1_julis-bremen.de.png (stored 0%)
# updating: labeled_data/-1_rationalstock.es.png (deflated 2%)
# updating: labeled_data/-1_linde-electronics.com.png (deflated 1%)
# updating: labeled_data/-1_mitsubishi-motors.pt.png (deflated 2%)
# updating: labeled_data/-1_nissanoflebanonnh.com.png (deflated 3%)
# updating: labeled_data/-1_thisissowgood.com.png (stored 0%)
# updating: labeled_data/-1_cvjm-augsburg.de.png (deflated 2%)
# updating: labeled_data/-1_starkeypro.com.png (deflated 1%)
# updating: labeled_data/-1_remax.fi.png (stored 0%)
# updating: labeled_data/-1_toyotaquezonavenue.com.ph.png (stored 0%)
# updating: labeled_data/-1_bosch-pt.com.cn.png (stored 0%)
# updating: labeled_data/-1_chicco.com.tr.png (stored 0%)
# updating: labeled_data/-1_grantthornton.az.png (deflated 0%)
# updating: labeled_data/-1_culliganofnashville.com.png (deflated 3%)
# updating: labeled_data/-1_invisalign.co.kr.png (stored 0%)
# updating: labeled_data/-1_mercyships.se.png (deflated 0%)
# updating: labeled_data/-1_monster.co.uk.png (stored 0%)
# updating: labeled_data/-1_kind-der-stadt.at.png (deflated 4%)
# updating: labeled_data/-1_stanbicbank.co.zm.png (stored 0%)
# updating: labeled_data/-1_mooresingapore.com.png (stored 0%)
# updating: labeled_data/-1_bestdrive.se.png (deflated 2%)
# updating: labeled_data/-1_pmcorp.mx.png (stored 0%)
# updating: labeled_data/-1_gulf-japan.com.png (deflated 0%)
# updating: labeled_data/-1_plastoplan.si.png (deflated 1%)
# updating: labeled_data/-1_worldoptionsgh.com.au.png (deflated 3%)
# updating: labeled_data/-1_workcircle.com.png (deflated 4%)
# updating: labeled_data/-1_mitsubishi-motors.com.kw.png (deflated 2%)
# updating: labeled_data/-1_gs1tn.org.png (deflated 0%)
# updating: labeled_data/-1_fitness4homesuperstore.com.png (deflated 0%)
# updating: labeled_data/-1_petercem-sensors.com.png (deflated 44%)
# updating: labeled_data/-1_vedanta-zincinternational.com.png (stored 0%)
# updating: labeled_data/-1_ibc-solar.jp.png (stored 0%)
# updating: labeled_data/-1_tupperware.es.png (deflated 15%)
# updating: labeled_data/-1_eru.com.ua.png (deflated 3%)
# updating: labeled_data/-1_minisouruguay.com.uy.png (deflated 5%)
# updating: labeled_data/-1_reedglobal.sg.png (deflated 54%)
# updating: labeled_data/-1_santillana.com.ar.png (stored 0%)
# updating: labeled_data/9_bakertilly.vg.png (stored 0%)
# updating: labeled_data/-1_intersport.com.cy.png (stored 0%)
# updating: labeled_data/-1_pingusenglish.com.tr.png (stored 0%)
# updating: labeled_data/-1_toyotacommonwealth.com.png (stored 0%)
# updating: labeled_data/-1_cvjm-muenchberg.de.png (deflated 2%)
# updating: labeled_data/-1_esseskincare.se.png (deflated 8%)
# updating: labeled_data/-1_renaultrycauto.es.png (stored 0%)
# updating: labeled_data/-1_berlitznouvelleaquitaine.fr.png (stored 0%)
# updating: labeled_data/-1_landi.swiss.png (stored 0%)
# updating: labeled_data/-1_secureparking.com.lb.png (deflated 2%)
# updating: labeled_data/-1_duracleanmaine.com.png (stored 0%)
# updating: labeled_data/-1_cvjm-nuembrecht.de.png (deflated 1%)
# updating: labeled_data/-1_pefc.dk.png (stored 0%)
# updating: labeled_data/-1_hertzhn.com.png (deflated 4%)
# updating: labeled_data/-1_toyotadolak.cz.png (deflated 4%)
# updating: labeled_data/-1_crocs.com.uy.png (deflated 2%)
# updating: labeled_data/-1_mazdaofchicagoland.com.png (deflated 9%)
# updating: labeled_data/-1_engie.nl.png (deflated 3%)
# updating: labeled_data/-1_tryg.com.png (deflated 2%)
# updating: labeled_data/-1_lamborghini-cannes.com.png (deflated 1%)
# updating: labeled_data/-1_kilewswest.com.png (stored 0%)
# updating: labeled_data/-1_johnsmedley.jp.png (stored 0%)
# updating: labeled_data/-1_ecslupsk.pl.png (stored 0%)
# updating: labeled_data/-1_regalsprings.com.mx.png (stored 0%)
# updating: labeled_data/-1_castsoftware.it.png (deflated 6%)
# updating: labeled_data/-1_pkfcaribbean.com.png (deflated 3%)
# updating: labeled_data/-1_stanbicbank.co.bw.png (deflated 0%)
# updating: labeled_data/-1_edenred.hu.png (stored 0%)
# updating: labeled_data/-1_freeportwestselfstorage.com.png (stored 0%)
# updating: labeled_data/-1_nestle.com.ve.png (deflated 3%)
# updating: labeled_data/-1_nutrienagsolutions.ca.png (stored 0%)
# updating: labeled_data/-1_lindt.com.au.png (deflated 2%)
# updating: labeled_data/-1_wwf.es.png (deflated 1%)
# updating: labeled_data/-1_childrenandteendentalfl.com.png (stored 0%)
# updating: labeled_data/-1_hsbcsaudi.com.png (deflated 5%)
# updating: labeled_data/-1_venaenergy.co.jp.png (deflated 1%)
# updating: labeled_data/-1_aeccglobal.com.bd.png (deflated 2%)
# updating: labeled_data/-1_duraclean.us.png (deflated 4%)
# updating: labeled_data/-1_moore.es.png (stored 0%)
# updating: labeled_data/-1_mazdalakeland.com.png (stored 0%)
# updating: labeled_data/-1_kumonla.com.png (stored 0%)
# updating: labeled_data/-1_mazdaofescondido.com.png (deflated 8%)
# updating: labeled_data/-1_yves-rocher.se.png (deflated 3%)
# updating: labeled_data/-1_internationalsos.co.jp.png (deflated 2%)
# updating: labeled_data/-1_medefloire.fr.png (deflated 2%)
# updating: labeled_data/-1_starkeypro.com.au.png (deflated 1%)
# updating: labeled_data/-1_citychain.co.th.png (deflated 6%)
# updating: labeled_data/-1_gwaliasweets.ca.png (deflated 14%)
# updating: labeled_data/-1_wuerth.my.png (deflated 0%)
# updating: labeled_data/-1_pkf.pt.png (deflated 3%)
# updating: labeled_data/-1_designpluz.com.png (deflated 2%)
# updating: labeled_data/-1_roca.com.tr.png (deflated 3%)
# updating: labeled_data/-1_heydudeshoes.es.png (stored 0%)
# updating: labeled_data/-1_keasyfit.it.png (stored 0%)
# updating: labeled_data/-1_kiavacaville.com.png (stored 0%)
# updating: labeled_data/-1_thebodyshop.si.png (deflated 56%)
# updating: labeled_data/-1_gallant-ocean.com.tw.png (deflated 9%)
# updating: labeled_data/-1_genan.com.png (deflated 2%)
# updating: labeled_data/-1_modshair.co.nz.png (deflated 6%)
# updating: labeled_data/-1_crif.com.tr.png (deflated 2%)
# updating: labeled_data/-1_kiaofoldsaybrook.com.png (stored 0%)
# updating: labeled_data/-1_budatec.de.png (deflated 3%)
# updating: labeled_data/-1_mazdaofsouthcharlotte.com.png (deflated 2%)
# updating: labeled_data/-1_mercyships.dk.png (deflated 0%)
# updating: labeled_data/-1_durableonline.com.sg.png (deflated 8%)
# updating: labeled_data/-1_matutis.de.png (deflated 2%)
# updating: labeled_data/-1_overheaddoorofterrehaute.com.png (stored 0%)
# updating: labeled_data/-1_middletemplevenue.org.uk.png (stored 0%)
# updating: labeled_data/-1_zkteco.me.png (deflated 3%)
# updating: labeled_data/-1_engie.pt.png (deflated 2%)
# updating: labeled_data/-1_starbucks.in.png (stored 0%)
# updating: labeled_data/-1_subaru.com.np.png (deflated 2%)
# updating: labeled_data/-1_cdlbarreiras.com.br.png (stored 0%)
# updating: labeled_data/-1_hyrox.es.png (deflated 3%)
# updating: labeled_data/-1_isuzu.net.my.png (deflated 15%)
# updating: labeled_data/-1_orient-food.sk.png (deflated 1%)
# updating: labeled_data/-1_hansa-flex.com.cn.png (stored 0%)
# updating: labeled_data/-1_fortprousa.com.png (stored 0%)
# updating: labeled_data/-1_wurth.com.mk.png (deflated 1%)
# updating: labeled_data/7_bbraun.se.png (deflated 1%)
# updating: labeled_data/-1_travelocarbooking.com.png (deflated 3%)
# updating: labeled_data/-1_kiwiqa.com.au.png (stored 0%)
# updating: labeled_data/-1_intersport.hr.png (deflated 2%)
# updating: labeled_data/-1_rotaryclubmedellin.org.png (stored 0%)
# updating: labeled_data/7_bbraun.ph.png (deflated 1%)
# updating: labeled_data/-1_subaru-bd.com.png (deflated 2%)
# updating: labeled_data/-1_arkaybeverages.com.png (stored 0%)
# updating: labeled_data/7_bbraun.com.ar.png (deflated 1%)
# updating: labeled_data/-1_avoncameroun.com.png (stored 0%)
# updating: labeled_data/-1_aviabienert.de.png (deflated 1%)
# updating: labeled_data/-1_wurth.es.png (deflated 0%)
# updating: labeled_data/-1_gulf.lu.png (stored 0%)
# updating: labeled_data/-1_bellaplanta.de.png (stored 0%)
# updating: labeled_data/-1_meggle.de.png (stored 0%)
# updating: labeled_data/-1_cdlcampina.org.br.png (stored 0%)
# updating: labeled_data/-1_aliaxis.bg.png (deflated 2%)
# updating: labeled_data/-1_bcurelaser.com.png (stored 0%)
# updating: labeled_data/-1_yonyou.com.hk.png (deflated 1%)
# updating: labeled_data/-1_pkfea.com.png (deflated 2%)
# updating: labeled_data/-1_eca-serel.de.png (deflated 18%)
# updating: labeled_data/-1_bakertilly.sg.png (deflated 0%)
# updating: labeled_data/-1_servier.co.za.png (deflated 2%)
# updating: labeled_data/-1_melgarcases.com.png (deflated 2%)
# updating: labeled_data/7_bbraun.ro.png (deflated 1%)
# updating: labeled_data/-1_extremeadventureraces.com.png (deflated 1%)
# updating: labeled_data/-1_honda-meaux.com.png (deflated 2%)
# updating: labeled_data/-1_pingusenglish.com.cy.png (deflated 1%)
# updating: labeled_data/-1_ymcatoledo.org.png (stored 0%)
# updating: labeled_data/-1_desjoyaux.de.png (deflated 2%)
# updating: labeled_data/-1_alchemia-nova.net.png (deflated 0%)
# updating: labeled_data/-1_fattalhotelgroup.com.png (deflated 2%)
# updating: labeled_data/-1_electrolux.com.mx.png (stored 0%)
# updating: labeled_data/-1_engie-africa.com.png (deflated 6%)
# updating: labeled_data/-1_linde-medica.es.png (stored 0%)
# updating: labeled_data/-1_saint-gobain.ru.png (stored 0%)
# updating: labeled_data/-1_mazdaofalexandria.com.png (stored 0%)
# updating: labeled_data/-1_xtransfer.cn.png (deflated 2%)
# updating: labeled_data/-1_wuerth.bg.png (deflated 5%)
# updating: labeled_data/-1_mazda.co.za.png (deflated 2%)
# updating: labeled_data/-1_zkteco.com.eg.png (deflated 5%)
# updating: labeled_data/-1_customneon.com.au.png (deflated 2%)
# updating: labeled_data/-1_saint-gobain.com.co.png (deflated 2%)
# updating: labeled_data/-1_wordans.it.png (stored 0%)
# updating: labeled_data/-1_cargoriga.ee.png (deflated 1%)
# updating: labeled_data/-1_edenredrewards.co.in.png (deflated 4%)
# updating: labeled_data/-1_sonepar.pe.png (deflated 1%)
# updating: labeled_data/-1_lindt.cz.png (deflated 2%)
# updating: labeled_data/-1_bauder.be.png (deflated 8%)
# updating: labeled_data/-1_ibc-solar.it.png (deflated 0%)
# updating: labeled_data/-1_ibc-solar.nl.png (stored 0%)
# updating: labeled_data/-1_lidl-immobilien.de.png (stored 0%)
# updating: labeled_data/-1_mapfre.com.sv.png (deflated 6%)
# updating: labeled_data/-1_aamcogolflinks.com.png (deflated 1%)
# updating: labeled_data/-1_hannainst.hr.png (deflated 2%)
# updating: labeled_data/-1_altenusa.com.png (stored 0%)
# updating: labeled_data/-1_iba-protontherapy.com.png (stored 0%)
# updating: labeled_data/-1_aon.lv.png (deflated 3%)
# updating: labeled_data/-1_noiseassessments.org.png (deflated 0%)
# updating: labeled_data/-1_meggle-foodingredients.de.png (deflated 1%)
# updating: labeled_data/-1_icafalinmobiliaria.cl.png (deflated 5%)
# updating: labeled_data/-1_ardex.com.tw.png (stored 0%)
# updating: labeled_data/-1_rotary6450.org.png (stored 0%)
# updating: labeled_data/-1_scte-prod.herokuapp.com.png (stored 0%)
# updating: labeled_data/-1_mitsubishi-motors.com.ar.png (stored 0%)
# updating: labeled_data/-1_svnvanguardla.com.png (deflated 1%)
# updating: labeled_data/-1_altriusconsulting.com.png (stored 0%)
# updating: labeled_data/-1_bluecardagency.ru.png (deflated 3%)
# updating: labeled_data/7_bbraun.pk.png (deflated 1%)
# updating: labeled_data/-1_warmupdeutschland.de.png (deflated 3%)
# updating: labeled_data/-1_mcdonalds.md.png (deflated 1%)
# updating: labeled_data/-1_overheaddoorbrookfield.com.png (deflated 2%)
# updating: labeled_data/-1_captrain.pl.png (deflated 5%)
# updating: labeled_data/-1_remax-go.com.ar.png (deflated 2%)
# updating: labeled_data/-1_albatroslogistic.ma.png (deflated 2%)
# updating: labeled_data/-1_plastoplan.rs.png (deflated 4%)
# updating: labeled_data/-1_mazda-sosnowiec-mirai.pl.png (deflated 3%)
# updating: labeled_data/-1_toyotapasongtamo.com.png (deflated 1%)
# updating: labeled_data/-1_culligantulsa.com.png (deflated 0%)
# updating: labeled_data/-1_weidner.ca.png (stored 0%)
# updating: labeled_data/-1_crocs.pl.png (deflated 5%)
# updating: labeled_data/-1_renaultcancun.com.mx.png (deflated 7%)
# updating: labeled_data/-1_cinnabon-egypt.com.png (stored 0%)
# updating: labeled_data/-1_polarysgroup.eu.png (stored 0%)
# updating: labeled_data/-1_scholpp.it.png (deflated 4%)
# updating: labeled_data/-1_renaultbank.es.png (deflated 4%)
# updating: labeled_data/-1_mtn.cg.png (deflated 3%)
# updating: labeled_data/9_bakertilly.lv.png (stored 0%)
# updating: labeled_data/-1_apolloclinicguwahati.co.in.png (deflated 2%)
# updating: labeled_data/-1_gloriasportsarena.com.tr.png (deflated 4%)
# updating: labeled_data/-1_ccusa.co.nz.png (deflated 1%)
# updating: labeled_data/-1_synlab.by.png (deflated 2%)
# updating: labeled_data/-1_modshair-stuttgart.de.png (deflated 4%)
# updating: labeled_data/-1_europa-union-sachsen.de.png (deflated 3%)
# updating: labeled_data/-1_wingarc.com.au.png (deflated 4%)
# updating: labeled_data/-1_spitexzug.ch.png (deflated 3%)
# updating: labeled_data/-1_whirlpoolservice.co.uk.png (deflated 3%)
# updating: labeled_data/-1_yves-rocher.de.png (deflated 0%)
# updating: labeled_data/-1_suttontools.co.nz.png (deflated 3%)
# updating: labeled_data/-1_greatplacetowork.com.ve.png (stored 0%)
# updating: labeled_data/-1_tupperwarefiesta.com.png (deflated 2%)
# updating: labeled_data/-1_crocs.ch.png (deflated 5%)
# updating: labeled_data/-1_avispl.de.png (deflated 4%)
# updating: labeled_data/-1_pixibeauty.co.uk.png (stored 0%)
# updating: labeled_data/-1_nissanmanufacturing.com.png (deflated 7%)
# updating: labeled_data/-1_linde-gas.sk.png (deflated 4%)
# updating: labeled_data/-1_cinnabon.ca.png (deflated 3%)
# updating: labeled_data/-1_mercanta.de.png (deflated 4%)
# updating: labeled_data/-1_niproaustralia.com.au.png (deflated 3%)
# updating: labeled_data/-1_savethechildren.mx.png (deflated 1%)
# updating: labeled_data/-1_isover.lv.png (deflated 3%)
# updating: labeled_data/-1_aamconorwalk.com.png (stored 0%)
# updating: labeled_data/-1_moorestoke.co.uk.png (stored 0%)
# updating: labeled_data/-1_nissanofthebronx.com.png (stored 0%)
# updating: labeled_data/-1_daikin-korea.co.kr.png (deflated 9%)
# updating: labeled_data/-1_shahshalalfood.com.png (stored 0%)
# updating: labeled_data/-1_aiesecargentina.org.png (stored 0%)
# updating: labeled_data/-1_fosterfarmsfoodservice.com.png (stored 0%)
# updating: labeled_data/-1_habitativ.org.png (deflated 0%)
# updating: labeled_data/-1_nextbikeczech.com.png (stored 0%)
# updating: labeled_data/-1_fronticsamerica.com.png (stored 0%)
# updating: labeled_data/-1_engie.co.uk.png (deflated 2%)
# updating: labeled_data/-1_medef31.fr.png (deflated 0%)
# updating: labeled_data/-1_steinbacher.pl.png (deflated 4%)
# updating: labeled_data/-1_crocs.cl.png (stored 0%)
# updating: labeled_data/-1_plameco-rheinsieg.de.png (stored 0%)
# updating: labeled_data/-1_decathlon.cz.png (deflated 1%)
# updating: labeled_data/-1_mediqdirekt.de.png (deflated 2%)
# updating: labeled_data/-1_kiacowansville.com.png (deflated 1%)
# updating: labeled_data/-1_moore-czech.cz.png (stored 0%)
# updating: labeled_data/-1_bbraun.pe.png (deflated 3%)
# updating: labeled_data/-1_fmc-symposium.cz.png (deflated 65%)
# updating: labeled_data/-1_amway.ca.png (stored 0%)
# updating: labeled_data/-1_ymcatrivalley.org.png (stored 0%)
# updating: labeled_data/-1_billygraham.ca.png (deflated 0%)
# updating: labeled_data/-1_rotary-bulgaria.org.png (stored 0%)
# updating: labeled_data/-1_airbnb.co.in.png (stored 0%)
# updating: labeled_data/-1_urmet.com.br.png (stored 0%)
# updating: labeled_data/-1_jscosccha.com.png (stored 0%)
# updating: labeled_data/-1_cbrain.com.png (deflated 4%)
# updating: labeled_data/-1_saint-gobain.ar.png (deflated 1%)
# updating: labeled_data/-1_freseniusmedicalcare.ca.png (deflated 1%)
# updating: labeled_data/-1_solutions30.nl.png (deflated 3%)
# updating: labeled_data/-1_lcvesta.nl.png (deflated 1%)
# updating: labeled_data/-1_salvationarmy.org.my.png (stored 0%)
# updating: labeled_data/-1_toyotaaydogan.com.tr.png (stored 0%)
# updating: labeled_data/-1_toyota.co.tz.png (deflated 1%)
# updating: labeled_data/-1_allianz.lu.png (stored 0%)
# updating: labeled_data/-1_cdvi.ca.png (stored 0%)
# updating: labeled_data/-1_eurotradus.eu.png (deflated 3%)
# updating: labeled_data/-1_mitsubishi-motors.qa.png (deflated 1%)
# updating: labeled_data/-1_aleris-pp.dk.png (deflated 26%)
# updating: labeled_data/-1_manpowergroup.com.sg.png (deflated 1%)
# updating: labeled_data/1_daikin-ce.com.png (deflated 4%)
# updating: labeled_data/-1_luminishealthcareers.org.png (deflated 1%)
# updating: labeled_data/-1_unglobalcompact.ca.png (stored 0%)
# updating: labeled_data/-1_servier.ge.png (deflated 3%)
# updating: labeled_data/9_bakertilly.lk.png (stored 0%)
# updating: labeled_data/-1_virtual-reality.school.png (stored 0%)
# updating: labeled_data/-1_kia.com.ni.png (deflated 5%)
# updating: labeled_data/-1_subway-franchise.fr.png (stored 0%)
# updating: labeled_data/-1_autosecuritas-ct-seysses.fr.png (deflated 3%)
# updating: labeled_data/-1_deprag.cz.png (deflated 3%)
# updating: labeled_data/-1_wheystore.vn.png (stored 0%)
# updating: labeled_data/-1_renaultzaragoza.com.png (stored 0%)
# updating: labeled_data/-1_toyota.com.mk.png (stored 0%)
# updating: labeled_data/-1_giacomini.cz.png (deflated 1%)
# updating: labeled_data/-1_educab.com.au.png (deflated 0%)
# updating: labeled_data/-1_santanderconsumer.fi.png (deflated 0%)
# updating: labeled_data/-1_pkf.com.tr.png (deflated 5%)
# updating: labeled_data/-1_pilotpen.it.png (stored 0%)
# updating: labeled_data/7_bbraun.com.vn.png (deflated 1%)
# updating: labeled_data/-1_mitsubishielectricmalaysia.com.png (deflated 2%)
# updating: labeled_data/-1_grantthornton.do.png (stored 0%)
# updating: labeled_data/-1_whirlpool.com.sg.png (deflated 0%)
# updating: labeled_data/-1_besins-healthcare.se.png (deflated 2%)
# updating: labeled_data/-1_renault.no.png (deflated 1%)
# updating: labeled_data/-1_eftech-international.com.png (deflated 2%)
# updating: labeled_data/-1_viessmann.ua.png (deflated 4%)
# updating: labeled_data/-1_mazdaofnewrochelle.com.png (deflated 1%)
# updating: labeled_data/-1_kia.com.uy.png (deflated 5%)
# updating: labeled_data/-1_ilmercatoambacht.nl.png (deflated 16%)
# updating: labeled_data/-1_actemium.at.png (deflated 0%)
# updating: labeled_data/-1_mapfre.pr.png (deflated 3%)
# updating: labeled_data/-1_hofmann-personal.cz.png (deflated 4%)
# updating: labeled_data/-1_toyotasanpablo.com.ph.png (deflated 0%)
# updating: labeled_data/-1_miniso.com.ec.png (deflated 1%)
# updating: labeled_data/-1_intersport-grandbornand.com.png (stored 0%)
# updating: labeled_data/-1_pakuacanada.com.png (stored 0%)
# updating: labeled_data/-1_poliform-spb.ru.png (deflated 31%)
# updating: labeled_data/-1_nerdsonsite.co.za.png (deflated 1%)
# updating: labeled_data/-1_mitsubishi-motors.fi.png (deflated 2%)
# updating: labeled_data/-1_panpuri.fr.png (deflated 4%)
# updating: labeled_data/-1_lidl-voyages.fr.png (stored 0%)
# updating: labeled_data/-1_specialistnutrition.us.png (deflated 2%)
# updating: labeled_data/-1_bosch-homecomfortgroup.com.png (stored 0%)
# updating: labeled_data/-1_pkfcr.co.nz.png (deflated 2%)
# updating: labeled_data/-1_rexel.ca.png (stored 0%)
# updating: labeled_data/-1_nobleprog.co.th.png (deflated 3%)
# updating: labeled_data/-1_pussyspace.net.png (stored 0%)
# updating: labeled_data/-1_aonassurances.com.png (deflated 3%)
# updating: labeled_data/-1_howden.co.il.png (deflated 4%)
# updating: labeled_data/-1_renaulttersa.com.mx.png (deflated 62%)
# updating: labeled_data/-1_steelhousegroup.ee.png (deflated 2%)
# updating: labeled_data/-1_enterpriserentacar.pl.png (deflated 1%)
# updating: labeled_data/-1_ymcaokc.org.png (deflated 1%)
# updating: labeled_data/-1_sprachschule-aktiv-kaiserslautern.de.png (stored 0%)
# updating: labeled_data/-1_bestrucksofmn.net.png (deflated 2%)
# updating: labeled_data/-1_kern-liebers.it.png (deflated 6%)
# updating: labeled_data/-1_hyundaitgv.ro.png (deflated 0%)
# updating: labeled_data/-1_coffeesmith.com.sg.png (stored 0%)
# updating: labeled_data/-1_bakertilly.com.ve.png (stored 0%)
# updating: labeled_data/-1_ohb-system.de.png (stored 0%)
# updating: labeled_data/-1_pirtek.se.png (deflated 2%)
# updating: labeled_data/-1_mazda.ru.png (deflated 1%)
# updating: labeled_data/-1_new-beauty.com.png (stored 0%)
# updating: labeled_data/-1_toyotabeerens.be.png (stored 0%)
# updating: labeled_data/-1_kiamotors.com.co.png (stored 0%)
# updating: labeled_data/-1_yves-rocher.ch.png (stored 0%)
# updating: labeled_data/-1_culligandesmoines.com.png (stored 0%)
# updating: labeled_data/-1_equansservices.com.png (stored 0%)
# updating: labeled_data/-1_franzcollection.com.png (deflated 0%)
# updating: labeled_data/-1_papasaveriospizzeria.com.png (stored 0%)
# updating: labeled_data/-1_husse.hu.png (stored 0%)
# ...
#   adding: labeled_data/12_aamcoparkvillemd.com.png (stored 0%)
#   adding: labeled_data/116_amnesty.se.png (stored 0%)
#   adding: labeled_data/28_mazda-autohaus-haeusler-fuerstenfeldbruck.de.png (stored 0%)
#   adding: labeled_data/191_mazdaofconshohocken.com.png (stored 0%)
#   adding: labeled_data/21_culliganofidaho.com.png (stored 0%)
#   adding: labeled_data/18_mazda-autohaus-roeser-grossmaischeid.de.png (deflated 0%)
#   adding: labeled_data/18_mazda-autohaus-schmidt-meschede.de.png (deflated 0%)
#   adding: labeled_data/120_duracell.fr.png (deflated 0%)
#   adding: labeled_data/164_renaultcampeche.mx.png (stored 0%)
#   adding: labeled_data/54_aamco-omahanorth.com.png (deflated 0%)
#   adding: labeled_data/12_aamcoaustin-burnetrd.com.png (stored 0%)
#   adding: labeled_data/176_toyotacetas.com.tr.png (deflated 47%)
#   adding: labeled_data/36_aamcoeastbrunswick.com.png (deflated 0%)
#   adding: labeled_data/41_honda-lemans.com.png (deflated 13%)
#   adding: labeled_data/12_aamcomarietta-cobbparkway.com.png (stored 0%)
#   adding: labeled_data/15_aamcotemeculaca.com.png (deflated 9%)
#   adding: labeled_data/147_metlife.com.ar.png (stored 0%)
#   adding: labeled_data/167_rotary-club-paris-se.org.png (stored 0%)
#   adding: labeled_data/110_furuno.fr.png (deflated 6%)
#   adding: labeled_data/170_tapflo.co.za.png (deflated 0%)
#   adding: labeled_data/28_mazda-autohaus-born-ludwigslust.de.png (stored 0%)
#   adding: labeled_data/18_mazda-autohaus-hansmann-kassel.de.png (deflated 0%)
#   adding: labeled_data/130_astrazeneca.no.png (stored 0%)
#   adding: labeled_data/240_veolia.ma.png (stored 0%)
#   adding: labeled_data/26_synlab.lt.png (stored 0%)
#   adding: labeled_data/57_kia-kurt-recklinghausen.de.png (deflated 7%)
#   adding: labeled_data/67_einhell.pl.png (deflated 26%)
#   adding: labeled_data/37_deheus.rs.png (stored 0%)
#   adding: labeled_data/23_murrelektronik.ro.png (deflated 1%)
#   adding: labeled_data/25_toyotaploiesti.ro.png (deflated 3%)
#   adding: labeled_data/305_job-impulse.mx.png (deflated 2%)
#   adding: labeled_data/216_nexi.hr.png (deflated 3%)
#   adding: labeled_data/153_engie-energia.pe.png (deflated 3%)
#   adding: labeled_data/75_vwswestgarth.com.png (deflated 4%)
#   adding: labeled_data/8_pkf.swiss.png (deflated 3%)
#   adding: labeled_data/81_ccusa.com.au.png (stored 0%)
#   adding: labeled_data/24_toyota-annecy.fr.png (stored 0%)
#   adding: labeled_data/178_spitex-imboden.ch.png (stored 0%)
#   adding: labeled_data/86_zalando.ch.png (deflated 2%)
#   adding: labeled_data/186_vbhtrgovina.si.png (stored 0%)
#   adding: labeled_data/150_baywa-re.fr.png (deflated 1%)
#   adding: labeled_data/271_siebtechnik-tema.co.uk.png (stored 0%)
#   adding: labeled_data/200_vbh.com.es.png (deflated 3%)
#   adding: labeled_data/152_siebtechnik-tema.nl.png (stored 0%)
#   adding: labeled_data/114_culligangrandisland.com.png (stored 0%)
#   adding: labeled_data/240_veolia.cn.png (stored 0%)
#   adding: labeled_data/268_lidl.lv.png (stored 0%)
#   adding: labeled_data/83_linexofstlouismo.com.png (stored 0%)
#   adding: labeled_data/184_mazdafwb.com.png (stored 0%)
#   adding: labeled_data/27_mersen.com.br.png (deflated 5%)
#   adding: labeled_data/221_gs1.ro.png (deflated 1%)
#   adding: labeled_data/115_greatplacetowork.com.vn.png (stored 0%)
#   adding: labeled_data/15_aamcohuntingtonbeachca.com.png (deflated 9%)
#   adding: labeled_data/274_renaultpatria.com.mx.png (deflated 6%)
#   adding: labeled_data/51_airbnb.com.br.png (deflated 0%)
#   adding: labeled_data/255_bakertilly.pt.png (deflated 1%)
#   adding: labeled_data/15_aamcocolumbus-clevelandave.com.png (deflated 9%)
#   adding: labeled_data/15_aamcobearde.com.png (deflated 9%)
#   adding: labeled_data/158_pkfmalta.com.png (deflated 1%)
#   adding: labeled_data/160_pirtek.nl.png (stored 0%)
#   adding: labeled_data/25_toyotaakkoyunlu.com.tr.png (deflated 3%)
#   adding: labeled_data/211_intersport-courchevel1850.com.png (deflated 3%)
#   adding: labeled_data/202_invisalign.fr.png (deflated 5%)
#   adding: labeled_data/157_funiber.sn.png (deflated 0%)
#   adding: labeled_data/54_aamcoreno.com.png (deflated 0%)
#   adding: labeled_data/18_mazda-autohaus-berlenbach-bergischgladbach.de.png (deflated 0%)
#   adding: labeled_data/106_entergy-arkansas.com.png (deflated 0%)
#   adding: labeled_data/273_wurth.sk.png (deflated 5%)
#   adding: labeled_data/101_greatplacetowork.com.au.png (stored 0%)
#   adding: labeled_data/63_nordicpharma.fr.png (deflated 5%)
#   adding: labeled_data/243_moog.es.png (deflated 4%)
#   adding: labeled_data/116_amnesty.is.png (deflated 1%)
#   adding: labeled_data/48_culliganwi.com.png (stored 0%)
#   adding: labeled_data/178_spitex-wuerenlos.ch.png (stored 0%)
#   adding: labeled_data/196_meggle-group.com.png (deflated 2%)
#   adding: labeled_data/169_roca.ro.png (deflated 11%)
#   adding: labeled_data/51_airbnb.com.au.png (deflated 0%)
#   adding: labeled_data/187_pearsonschoolsandfecolleges.co.uk.png (stored 0%)
#   adding: labeled_data/48_culliganporthuron.com.png (stored 0%)
#   adding: labeled_data/133_mateco.bg.png (deflated 3%)
#   adding: labeled_data/21_culligantotalwaterbaraboo.com.png (stored 0%)
#   adding: labeled_data/18_mazda-autohaus-elstner-jena.de.png (deflated 0%)
#   adding: labeled_data/115_greatplacetowork.com.ar.png (stored 0%)
#   adding: labeled_data/46_bbraun.ca.png (deflated 3%)
#   adding: labeled_data/284_hyundaiblacktown.com.au.png (deflated 0%)
#   adding: labeled_data/208_tupperware.com.ar.png (deflated 6%)
#   adding: labeled_data/18_mazda-autohaus-suedring-datteln.de.png (deflated 0%)
#   adding: labeled_data/51_airbnb.ca.png (deflated 0%)
#   adding: labeled_data/18_mazda-autohaus-gerhard-figge-waldeck-hoeringhausen.de.png (deflated 0%)
#   adding: labeled_data/143_bbraun.nl.png (stored 0%)
#   adding: labeled_data/63_nordicpharma.co.uk.png (deflated 4%)
#   adding: labeled_data/233_mazda-krakow-kazokuluzar.pl.png (stored 0%)
#   adding: labeled_data/136_bosch-pt.com.my.png (deflated 0%)
#   adding: labeled_data/12_aamcomcallen.com.png (stored 0%)
#   adding: labeled_data/12_aamcoanaheim.net.png (stored 0%)
#   adding: labeled_data/12_aamcooklahomacity-edmond.com.png (stored 0%)
#   adding: labeled_data/12_aamcolakeworth.com.png (stored 0%)
#   adding: labeled_data/50_linde.bo.png (stored 0%)
#   adding: labeled_data/128_kawasaki-magdeburg.de.png (deflated 16%)
#   adding: labeled_data/254_bbraun-vetcare.nl.png (deflated 33%)
#   adding: labeled_data/198_aeccglobal.my.png (deflated 3%)
#   adding: labeled_data/21_culligannc.com.png (stored 0%)
#   adding: labeled_data/25_toyotaderinderekocak.com.tr.png (deflated 3%)
#   adding: labeled_data/189_axa-assistance.cz.png (stored 0%)
#   adding: labeled_data/80_hansa-flex.at.png (deflated 4%)
#   adding: labeled_data/58_europcar.rs.png (stored 0%)
#   adding: labeled_data/261_goliathgames.es.png (stored 0%)
#   adding: labeled_data/143_bbraun.com.my.png (stored 0%)
#   adding: labeled_data/15_aamcoroanokeva.com.png (deflated 9%)
#   adding: labeled_data/18_mazda-autohaus-kopke-bendel-marl.de.png (deflated 0%)
#   adding: labeled_data/249_sephora.pl.png (stored 0%)
#   adding: labeled_data/21_culliganmonroe.com.png (stored 0%)
#   adding: labeled_data/12_aamcocovinaca.com.png (stored 0%)
#   adding: labeled_data/314_pkf-l.com.png (deflated 2%)
#   adding: labeled_data/59_funiber.it.png (deflated 1%)
#   adding: labeled_data/153_engieservices.us.png (deflated 2%)
#   adding: labeled_data/288_chicco.pl.png (stored 0%)
#   adding: labeled_data/125_veolia.co.za.png (stored 0%)
#   adding: labeled_data/246_lindt.at.png (deflated 4%)
#   adding: labeled_data/12_aamcoscottsdaleairpark.com.png (stored 0%)
#   adding: labeled_data/213_servier.co.th.png (deflated 1%)
#   adding: labeled_data/50_lindeoilandgas.com.png (stored 0%)
#   adding: labeled_data/66_skoda-clermontferrand.fr.png (deflated 25%)
#   adding: labeled_data/146_atalian.hu.png (deflated 2%)
#   adding: labeled_data/69_einhell.cz.png (deflated 52%)
#   adding: labeled_data/269_adecco.ie.png (deflated 4%)
#   adding: labeled_data/49_holidayland-roedermark.de.png (stored 0%)
#   adding: labeled_data/167_rotary-club-strasbourg.org.png (stored 0%)
#   adding: labeled_data/272_reedglobal.cz.png (deflated 0%)
#   adding: labeled_data/21_culliganofsouthwestwisconsin.com.png (stored 0%)
#   adding: labeled_data/305_job-impulse.pt.png (deflated 1%)
#   adding: labeled_data/63_nordicpharma.be.png (deflated 4%)
#   adding: labeled_data/21_culliganwatertreatment.com.png (stored 0%)
#   adding: labeled_data/32_aliaxis.hu.png (deflated 1%)
#   adding: labeled_data/42_mazda.nl.png (deflated 3%)
#   adding: labeled_data/104_nestle.com.tw.png (stored 0%)
#   adding: labeled_data/315_daikin.com.mx.png (stored 0%)
#   adding: labeled_data/104_nestle.si.png (stored 0%)
#   adding: labeled_data/46_bbraun.pt.png (deflated 3%)
#   adding: labeled_data/124_freseniuskidneycare.au.png (deflated 28%)
#   adding: labeled_data/193_pingusenglish.ee.png (stored 0%)
#   adding: labeled_data/234_budgetinternational.com.png (stored 0%)
#   adding: labeled_data/220_krugerkaldnes.no.png (stored 0%)
#   adding: labeled_data/205_kia-fischer-cottbus.de.png (deflated 8%)
#   adding: labeled_data/252_allianz.mg.png (stored 0%)
#   adding: labeled_data/18_mazda-autohaus-albers-doerpen.de.png (deflated 0%)
#   adding: labeled_data/121_toyotabacau.ro.png (stored 0%)
#   adding: labeled_data/68_gjw-hessen.de.png (stored 0%)
#   adding: labeled_data/38_edenred.cl.png (stored 0%)
#   adding: labeled_data/178_spitexniesen.ch.png (stored 0%)
#   adding: labeled_data/213_servier.ua.png (deflated 1%)
#   adding: labeled_data/113_bbraun.bg.png (deflated 2%)
#   adding: labeled_data/71_pefc.be.png (deflated 0%)
#   adding: labeled_data/178_spitexmuri.ch.png (stored 0%)
#   adding: labeled_data/204_vans.fr.png (deflated 3%)
#   adding: labeled_data/137_nobleprog.ro.png (deflated 3%)
#   adding: labeled_data/0_medef-htcis.com.png (stored 0%)
#   adding: labeled_data/249_sephora.ro.png (stored 0%)
#   adding: labeled_data/67_einhell.nl.png (deflated 5%)
#   adding: labeled_data/283_airbnb.si.png (stored 0%)
#   adding: labeled_data/28_mazda-autopark-rath-krefeld.de.png (stored 0%)
#   adding: labeled_data/124_freseniuskidneycare.ph.png (deflated 28%)
#   adding: labeled_data/107_daikin.ch.png (stored 0%)
#   adding: labeled_data/178_spitexzh.ch.png (stored 0%)
#   adding: labeled_data/23_murrelektronik.fi.png (deflated 1%)
#   adding: labeled_data/48_culliganchampaign.com.png (stored 0%)
#   adding: labeled_data/4_subaruqatar.com.png (deflated 2%)
#   adding: labeled_data/269_adecco.co.th.png (deflated 4%)
#   adding: labeled_data/28_mazda-autohaus-voigtlaender-meyer-hamburg.de.png (stored 0%)
#   adding: labeled_data/139_infiniti-dubai.com.png (deflated 4%)
#   adding: labeled_data/106_entergy-neworleans.com.png (deflated 0%)
#   adding: labeled_data/23_murrelektronik.cz.png (deflated 1%)
#   adding: labeled_data/196_meggle.it.png (deflated 2%)
#   adding: labeled_data/60_cdviplastics.com.png (deflated 42%)
#   adding: labeled_data/12_aamcostuartfl.com.png (stored 0%)
#   adding: labeled_data/213_servier.es.png (deflated 1%)
#   adding: labeled_data/73_kia-schunke-aurich.de.png (stored 0%)
#   adding: labeled_data/21_culligantotalwater.com.png (stored 0%)
#   adding: labeled_data/15_aamcocapistranobeachca.com.png (deflated 9%)
#   adding: labeled_data/12_aamcoglendaleoldtown.com.png (stored 0%)
#   adding: labeled_data/230_toysrus.com.ph.png (stored 0%)
#   adding: labeled_data/12_aamcocharlottesville.com.png (stored 0%)
#   adding: labeled_data/54_aamcogastonianc.com.png (deflated 0%)
#   adding: labeled_data/159_mapfre.com.py.png (stored 0%)
#   adding: labeled_data/165_rsmuk.com.png (deflated 5%)
#   adding: labeled_data/270_esseskincare.co.uk.png (deflated 2%)
#   adding: labeled_data/21_culliganregina.com.png (stored 0%)
#   adding: labeled_data/30_spitex-gersau.ch.png (stored 0%)
#   adding: labeled_data/63_nordicpharma.ch.png (deflated 5%)
#   adding: labeled_data/155_asendia.es.png (deflated 3%)
#   adding: labeled_data/36_aamcomiddletownny.com.png (deflated 0%)
#   adding: labeled_data/14_infiniti.mx.png (stored 0%)
#   adding: labeled_data/57_kia-penning-zetelneuenburg.de.png (deflated 7%)
#   adding: labeled_data/209_hertz.com.cy.png (deflated 5%)
#   adding: labeled_data/51_airbnb.ba.png (deflated 0%)
#   adding: labeled_data/12_aamcoroundrocktx.com.png (stored 0%)
#   adding: labeled_data/250_toyota.com.np.png (deflated 2%)
#   adding: labeled_data/87_linde-gas.com.png (stored 0%)
#   adding: labeled_data/26_affidea.pl.png (stored 0%)
#   adding: labeled_data/245_savethechildren.it.png (deflated 1%)
#   adding: labeled_data/258_zktecoma.com.png (deflated 2%)
#   adding: labeled_data/137_nobleprog.com.ar.png (deflated 4%)
#   adding: labeled_data/64_inductotherm-group-france.fr.png (stored 0%)
#   adding: labeled_data/202_invisalign.ch.png (deflated 6%)
#   adding: labeled_data/120_duracell-me.com.png (deflated 0%)
#   adding: labeled_data/262_mazda112.com.png (deflated 7%)
#   adding: labeled_data/11_synlab.de.png (deflated 4%)
#   adding: labeled_data/51_airbnb.com.ar.png (deflated 0%)
#   adding: labeled_data/48_culliganwaternebraska.com.png (stored 0%)
#   adding: labeled_data/90_toyota-innviertel.at.png (deflated 1%)
#   adding: labeled_data/42_mazdaofmidland.com.png (deflated 2%)
#   adding: labeled_data/25_toyotamezcar.com.tr.png (deflated 3%)
#   adding: labeled_data/98_europa-union-havelland.de.png (stored 0%)
#   adding: labeled_data/114_culliganhoriconwatertown.com.png (stored 0%)
#   adding: labeled_data/145_vans.co.nz.png (stored 0%)
#   adding: labeled_data/100_honda-grenoble.com.png (stored 0%)
#   adding: labeled_data/287_saint-gobain-solutions.nl.png (deflated 2%)
#   adding: labeled_data/100_honda-mulhouse.com.png (stored 0%)
#   adding: labeled_data/12_aamcophoenixmaryvale.com.png (stored 0%)
#   adding: labeled_data/213_servier.lv.png (deflated 1%)
#   adding: labeled_data/73_kia-ds-lampertheim.de.png (stored 0%)
#   adding: labeled_data/178_spitex.sg.png (stored 0%)
#   adding: labeled_data/28_mazda-service-koch-ludwigsfelde.de.png (stored 0%)
#   adding: labeled_data/286_ebay.pl.png (deflated 3%)
#   adding: labeled_data/53_bauder.fr.png (deflated 4%)
#   adding: labeled_data/15_aamcohialeahfl.com.png (deflated 9%)
#   adding: labeled_data/197_engieresources.com.png (deflated 3%)
#   adding: labeled_data/12_aamcotracyca.com.png (stored 0%)
#   adding: labeled_data/23_murrelektronik.it.png (deflated 1%)
#   adding: labeled_data/237_statkraft.com.tr.png (stored 0%)
#   adding: labeled_data/92_aamco-newbraunfels.com.png (stored 0%)
#   adding: labeled_data/176_toyotakuzen.com.tr.png (deflated 47%)
#   adding: labeled_data/74_pingusenglish.my.png (stored 0%)
#   adding: labeled_data/41_honda-lille.com.png (deflated 13%)
#   adding: labeled_data/110_furuno.it.png (deflated 6%)
#   adding: labeled_data/122_shopee.com.co.png (deflated 2%)
#   adding: labeled_data/252_allianzgloballife.com.png (stored 0%)
#   adding: labeled_data/12_aamcooklahomacity-yukon.com.png (stored 0%)
#   adding: labeled_data/115_greatplacetowork.com.pe.png (stored 0%)
#   adding: labeled_data/94_misterwhat.com.br.png (deflated 37%)
#   adding: labeled_data/100_honda-villebon.com.png (stored 0%)
#   adding: labeled_data/292_nutricia.pt.png (deflated 3%)
#   adding: labeled_data/200_vbh.be.png (deflated 3%)
#   adding: labeled_data/156_job-impulse.hu.png (deflated 2%)
#   adding: labeled_data/25_toyotaparmaksizlar.com.tr.png (deflated 3%)
#   adding: labeled_data/104_nestle.com.bd.png (stored 0%)
#   adding: labeled_data/147_metlife.com.bd.png (stored 0%)
#   adding: labeled_data/151_isuzugyor.hu.png (deflated 8%)
#   adding: labeled_data/22_plameco-huizen.nl.png (stored 0%)
#   adding: labeled_data/27_mersen.hu.png (deflated 5%)
#   adding: labeled_data/18_mazda-autohaus-kaschmieder-waren.de.png (deflated 0%)
#   adding: labeled_data/33_servier.nl.png (deflated 0%)
#   adding: labeled_data/291_grantthornton.com.pa.png (deflated 0%)
#   adding: labeled_data/155_asendia.de.png (deflated 3%)
#   adding: labeled_data/112_allianz-kuhlemann.de.png (stored 0%)
#   adding: labeled_data/170_tapflo.at.png (deflated 0%)
#   adding: labeled_data/129_analytik-jena.ru.png (deflated 3%)
#   adding: labeled_data/150_baywa-re.com.au.png (deflated 1%)
#   adding: labeled_data/205_kia-schmid-hoehenkirchen.de.png (deflated 8%)
